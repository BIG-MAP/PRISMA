# %% [markdown]
# ## Generate data to load in examples

# %%
import numpy as np
import pandas as pd
import prisma.lineshapes
import bqplot.pyplot as plt

# %%
x = np.arange(200,1500,2)
params1 = [200,650,50]
params2 = [500,730,10]
params3 = [300,900,20]
noise = 40*np.random.rand(len(x))
baseline =  3e-4*x**2

spectra_dict = {}
for n in range(20):
    params1 = [(1-0.005*n)*params1[0],params1[1],params1[2]]
    params2 = [params2[0],params2[1]+0.5*n,params2[2]]
    params3 = [(1+0.005*n)*params3[0],params3[1]+n,params3[2]]
    spectra_dict['spectrum_{}'.format(n)] = prisma.lineshapes.lorentzians(3)(x, 0, *params1, *params2, *params3) + noise + baseline

# %%
# lor_sum = prisma.lineshapes.lorentzians(3)(x, 0, *params1, *params2, *params3)

# %%
df = pd.DataFrame(spectra_dict, index=x)

# %%
df
# Out:
#       spectrum_0  spectrum_1  spectrum_2  spectrum_3  spectrum_4  spectrum_5  \
# 200    31.126998   31.114990   31.091101   31.055644   31.009120   30.952201
# 202    35.725273   35.713155   35.689045   35.653262   35.606309   35.548864
# 204    39.462947   39.450717   39.426384   39.390269   39.342881   39.284904
# 206    42.078921   42.066577   42.042019   42.005568   41.957739   41.899222
# 208    53.337539   53.325081   53.300292   53.263502   53.215225   53.156161
# ...          ...         ...         ...         ...         ...         ...
# 1490  668.024331  668.023810  668.022877  668.021771  668.020879  668.020733
# 1492  695.034684  695.034156  695.033206  695.032074  695.031141  695.030936
# 1494  675.358738  675.358202  675.357237  675.356078  675.355106  675.354844
# 1496  704.964266  704.963723  704.962742  704.961558  704.960547  704.960229
# 1498  686.727354  686.726804  686.725807  686.724598  686.723549  686.723176
#
#       spectrum_6  spectrum_7  spectrum_8  spectrum_9  spectrum_10  \
# 200    30.885720   30.810649   30.728084   30.639214    30.545302
# 202    35.481768   35.406003   35.322671   35.232974    35.138185
# 204    39.217185   39.140714   39.056606   38.966071    38.870394
# 206    41.830871   41.753687   41.668791   41.577407    41.480829
# 208    53.087171   53.009262   52.923569   52.831323    52.733833
# ...          ...         ...         ...         ...          ...
# 1490  668.022032  668.025661  668.032715  668.044544   668.062810
# 1492  695.032154  695.035668  695.042567  695.054186   695.072172
# 1494  675.355981  675.359383  675.366129  675.377542   675.395252
# 1496  704.961286  704.964578  704.971173  704.982384   704.999822
# 1498  686.724155  686.727339  686.733787  686.744797   686.761968
#
#       spectrum_11  spectrum_12  spectrum_13  spectrum_14  spectrum_15  \
# 200     30.447659    30.347617    30.246507    30.145634    30.046259
# 202     35.039628    34.938644    34.836576    34.734741    34.634411
# 204     38.770909    38.668971    38.565932    38.463122    38.361823
# 206     41.380404    41.277498    41.173476    41.069678    40.967396
# 208     52.632455    52.528568    52.423549    52.318748    52.215471
# ...           ...          ...          ...          ...          ...
# 1490   668.089564   668.127363   668.179431   668.249887   668.344083
# 1492   695.098554   695.135861   695.187280   695.256882   695.349947
# 1494   675.421267   675.458090   675.508871   675.577631   675.669584
# 1496   705.025476   705.061823   705.111975   705.179906   705.270764
# 1498   686.787267   686.823144   686.872677   686.939792   687.029573
#
#       spectrum_16  spectrum_17  spectrum_18  spectrum_19
# 200     29.949584    29.856736    29.768757    29.686602
# 202     34.536796    34.443032    34.354171    34.271173
# 204     38.263255    38.168563    38.078808    37.994957
# 206     40.867862    40.772230    40.681567    40.596851
# 208     52.114957    52.018371    51.926789    51.841195
# ...           ...          ...          ...          ...
# 1490   668.469080   668.634373   668.852967   669.143031
# 1492   695.473444   695.636731   695.852615   696.138972
# 1494   675.791605   675.952918   676.166137   676.448854
# 1496   705.391332   705.550703   705.761304   706.040444
# 1498   687.148710   687.306172   687.514197   687.789823
#
# [650 rows x 20 columns]

# %%
plt.plot(df.index, df['spectrum_0'])
plt.plot(df.index, df['spectrum_9'])
plt.plot(df.index, df['spectrum_19'])
plt.show()
# Out:
# VBox(children=(Figure(axes=[Axis(scale=LinearScale(), side='bottom'), Axis(orientation='vertical', scale=Linea…

# %%
df.to_csv('synthetic_dataset.csv')

# %%
for column in df.columns:
    df[column].to_csv(column+'.txt', sep=' ', header=False)
